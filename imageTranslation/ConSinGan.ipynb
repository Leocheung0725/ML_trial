# %%
# !git clone https://github.com/tohinz/ConSinGAN.git
# Out:
# Cloning into 'ConSinGAN'...
# remote: Enumerating objects: 1597, done.
# remote: Counting objects: 100% (84/84), done.
# remote: Compressing objects: 100% (30/30), done.
# remote: Total 1597 (delta 71), reused 56 (delta 54), pack-reused 1513
# Receiving objects: 100% (1597/1597), 80.44 MiB | 16.58 MiB/s, done.
# Resolving deltas: 100% (194/194), done.

# %%
# %cd ConSinGAN
# Out:
# /content/ConSinGAN

# %%
# !pip install -r requirements.txt --ignore-installed --force-reinstall
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Using cached absl_py-0.9.0-py3-none-any.whl
# ...
#   Using cached albumentations-0.4.3-py3-none-any.whl
# ...
#   Using cached cachetools-4.0.0-py3-none-any.whl (10 kB)
# ...
#   Using cached certifi-2019.11.28-py2.py3-none-any.whl (156 kB)
# ...
#   Using cached chardet-3.0.4-py2.py3-none-any.whl (133 kB)
# ...
#   Using cached cycler-0.10.0-py2.py3-none-any.whl (6.5 kB)
# ...
#   Using cached decorator-4.4.2-py2.py3-none-any.whl (9.2 kB)
# ...
#   Using cached future-0.18.2-py3-none-any.whl
# ...
#   Using cached google_auth-1.11.3-py2.py3-none-any.whl (76 kB)
# ...
#   Using cached google_auth_oauthlib-0.4.1-py2.py3-none-any.whl (18 kB)
# ...
#   Using cached grpcio-1.27.2-cp37-cp37m-manylinux2010_x86_64.whl (2.7 MB)
# ...
#   Using cached idna-2.9-py2.py3-none-any.whl (58 kB)
# ...
#   Using cached imageio-2.8.0-py3-none-any.whl (3.3 MB)
# ...
#   Using cached imgaug-0.2.6-py3-none-any.whl
# ...
#   Using cached joblib-0.14.1-py2.py3-none-any.whl (294 kB)
# ...

# %%
# !pip install ipykernel
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 132 kB 28.8 MB/s
# ...
#      |████████████████████████████████| 132 kB 50.9 MB/s
# ...
#      |████████████████████████████████| 423 kB 63.5 MB/s
# ...
#      |████████████████████████████████| 1.8 MB 51.4 MB/s
# ...
#      |████████████████████████████████| 793 kB 42.6 MB/s
# ...
#      |████████████████████████████████| 40 kB 6.8 MB/s
# ...
#      |████████████████████████████████| 381 kB 55.6 MB/s
# ...
#      |████████████████████████████████| 59 kB 3.4 MB/s
# ...
#      |████████████████████████████████| 1.6 MB 35.0 MB/s
# ...
#      |████████████████████████████████| 100 kB 12.3 MB/s
# ...
#      |████████████████████████████████| 247 kB 72.9 MB/s
# ...
#      |████████████████████████████████| 88 kB 8.6 MB/s
# ...
#   Attempting uninstall: tornado
#     Found existing installation: tornado 5.1.1
#     Uninstalling tornado-5.1.1:
#       Successfully uninstalled tornado-5.1.1
# ...

# %%
# !python main_train.py --gpu 0 --train_mode generation --input_name Images/Generation/Tree33.png
# Out:
# Training model (TrainedModels/Tree33/2022_08_02_02_39_31_generation_train_depth_3_lr_scale_0.1_act_lrelu_0.05)
# Training model with the following parameters:
# 	 number of stages: 6
# 	 number of concurrently trained stages: 3
# 	 learning rate scaling: 0.1
# 	 non-linearity: lrelu
# Training on image pyramid: [torch.Size([1, 3, 25, 25]), torch.Size([1, 3, 33, 33]), torch.Size([1, 3, 45, 45]), torch.Size([1, 3, 72, 72]), torch.Size([1, 3, 158, 158]), torch.Size([1, 3, 250, 250])]
#
# stage [0/5]::   0% 0/2000 [00:00<?, ?it/s]THCudaCheck FAIL file=/pytorch/aten/src/THC/THCGeneral.cpp line=383 error=11 : invalid argument
# stage [0/5]:: 100% 2000/2000 [00:52<00:00, 37.87it/s]
# stage [1/5]:: 100% 2000/2000 [01:01<00:00, 32.74it/s]
# stage [2/5]:: 100% 2000/2000 [01:08<00:00, 29.09it/s]
# stage [3/5]:: 100% 2000/2000 [01:12<00:00, 27.54it/s]
# stage [4/5]:: 100% 2000/2000 [13:25<00:00,  1.78it/s]
# stage [5/5]:: 100% 2000/2000 [19:47<00:00,  1.06it/s]
# ...

# %%
# !python evaluate_model.py --gpu 0 --model_dir /content/ConSinGAN/TrainedModels/Tree33/2022_08_02_02_39_31_generation_train_depth_3_lr_scale_0.1_act_lrelu_0.05 --num_samples 50
# Out:
# Loading models...
# Generating Samples...
# THCudaCheck FAIL file=/pytorch/aten/src/THC/THCGeneral.cpp line=383 error=11 : invalid argument
# Done. Results saved at: /content/ConSinGAN/TrainedModels/Tree33/2022_08_02_02_39_31_generation_train_depth_3_lr_scale_0.1_act_lrelu_0.05/Evaluation

# %%
# !zip -r /content/Tree33.zip /content/ConSinGAN/TrainedModels/Tree33/2022_08_02_02_39_31_generation_train_depth_3_lr_scale_0.1_act_lrelu_0.05
# Out:
#   adding: content/ConSinGAN/TrainedModels/Tree33/2022_08_02_02_39_31_generation_train_depth_3_lr_scale_0.1_act_lrelu_0.05/ (stored 0%)
#   adding: content/ConSinGAN/TrainedModels/Tree33/2022_08_02_02_39_31_generation_train_depth_3_lr_scale_0.1_act_lrelu_0.05/main_train.py (deflated 69%)
#   adding: content/ConSinGAN/TrainedModels/Tree33/2022_08_02_02_39_31_generation_train_depth_3_lr_scale_0.1_act_lrelu_0.05/G.pth (deflated 8%)
#   adding: content/ConSinGAN/TrainedModels/Tree33/2022_08_02_02_39_31_generation_train_depth_3_lr_scale_0.1_act_lrelu_0.05/3/ (stored 0%)
#   adding: content/ConSinGAN/TrainedModels/Tree33/2022_08_02_02_39_31_generation_train_depth_3_lr_scale_0.1_act_lrelu_0.05/3/reconstruction_1501.jpg (deflated 6%)
#   adding: content/ConSinGAN/TrainedModels/Tree33/2022_08_02_02_39_31_generation_train_depth_3_lr_scale_0.1_act_lrelu_0.05/3/reconstruction_1001.jpg (deflated 6%)
# ...
