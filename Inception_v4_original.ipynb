# %%
#CNN - Inception v4
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
# Out:
# Num GPUs Available:  1

# %%
#import the dataset
(x_train, y_train), (x_test, y_test) = keras.datasets.cifar10.load_data()
label_names = ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']
#Transform to tensor dataset
train_ds = tf.data.Dataset.from_tensor_slices((x_train,y_train))
test_ds = tf.data.Dataset.from_tensor_slices((x_test,y_test))
#each element contains two subelement, including x (32, 32, 3) and y (1 value)
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 4s 0us/step
# 170508288/170498071 [==============================] - 4s 0us/step

# %%
#preprocess the data
def process_image(image,label):
    image=tf.image.per_image_standardization(image)
    image=tf.image.resize(image,(299,299))
    
    return image,label
train_ds_size=tf.data.experimental.cardinality(train_ds).numpy()
test_ds_size=tf.data.experimental.cardinality(test_ds).numpy()
print('Train size:',train_ds_size)
print('Test size:',test_ds_size)
# Out:
# Train size: 50000
# Test size: 10000

# %%
#Data transformation
train_ds=(train_ds
          .map(process_image)
          .shuffle(buffer_size = 45000)
          .batch(batch_size=32,drop_remainder=True)
         )
test_ds=(test_ds
          .map(process_image)
          .shuffle(buffer_size=10000)
          .batch(batch_size=32,drop_remainder=True)
         )

# %%
#normal conv with bn and activation
def conv2d(input_layer, filters, kernel_tuple, strides=1, padding="same", use_bias=False):
    #each conv2d would have bn and activation
    conv = layers.Conv2D(filters=filters, kernel_size=kernel_tuple, \
                        strides=strides, padding=padding, use_bias=use_bias)(input_layer)
    bn = layers.BatchNormalization(momentum=0.9997, scale=False)(conv)
    activation = layers.Activation('relu')(bn)
    return activation

#stem part
def stem(input_layer, n=7):
    x = conv2d(input_layer, 32, 3, strides=2, padding="valid")
    x = conv2d(x, 32, 3, padding="valid")
    x = conv2d(x, 64, 3)
    #split
    conv1 = conv2d(x, 96, 3, strides=2, padding="valid")
    maxpool = layers.MaxPooling2D(pool_size=3, strides=2, padding='valid')(x)
    #filter concat
    x = layers.concatenate([conv1, maxpool], axis=-1)
    #split
    #line 1
    conv1_1 = conv2d(x, 64, 1)
    conv1_2 = conv2d(conv1_1, 96, 3, padding='valid')
    #line 2
    conv2_1 = conv2d(x, 64, 1)
    conv2_2 = conv2d(conv2_1, 64, (n, 1))
    conv2_3 = conv2d(conv2_2, 64, (1, n))
    conv2_4 = conv2d(conv2_3, 96, 3, padding='valid')
    #filter concat
    x = layers.concatenate([conv1_2, conv2_4], axis=-1)
    
    return x

def inceptionA(input_layer):
    #line 1
    avg = layers.AveragePooling2D(pool_size = 3,strides = 1,padding = 'same')(input_layer)
    conv1_1 = conv2d(avg, 96, 1)
    #line 2
    conv2_1 = conv2d(input_layer, 96, 1)
    #line 3
    conv3_1 = conv2d(input_layer, 64, 1)
    conv3_2 = conv2d(conv3_1, 96, 3)
    #line 4
    conv4_1 = conv2d(input_layer, 64, 1)
    conv4_2 = conv2d(conv4_1, 96, 3)
    conv4_3 = conv2d(conv4_2, 96, 3)
    #filter concat
    x = layers.concatenate([conv1_1, conv2_1, conv3_2, conv4_3], axis=-1)
    
    return x

def inceptionB(input_layer, n=7):
    #line 1
    avg = layers.AveragePooling2D(pool_size = 3,strides = 1,padding = 'same')(input_layer)
    conv1_1 = conv2d(avg, 128, 1)
    #line 2
    conv2_1 = conv2d(input_layer, 384, 1)
    #line 3
    conv3_1 = conv2d(input_layer, 192, 1)
    conv3_2 = conv2d(conv3_1, 224, (1, n))
    conv3_3 = conv2d(conv3_2, 256, (1, n))
    #line 4
    conv4_1 = conv2d(input_layer, 192, 1)
    conv4_2 = conv2d(conv4_1, 192, (1, n))
    conv4_3 = conv2d(conv4_2, 224, (n, 1))
    conv4_4 = conv2d(conv4_3, 224, (1, n))
    conv4_5 = conv2d(conv4_4, 256, (n, 1))
    #filter concat
    x = layers.concatenate([conv1_1, conv2_1, conv3_3, conv4_5], axis=-1)
    
    return x

def inceptionC(input_layer, n=3):
    #line 1
    avg = layers.AveragePooling2D(pool_size = 3,strides = 1,padding = 'same')(input_layer)
    conv1_1 = conv2d(avg, 256, 1)
    #line 2
    conv2_1 = conv2d(input_layer, 256, 1)
    #line 3
    conv3 = conv2d(input_layer, 384, 1)
    #line 3-1
    conv3_1 = conv2d(conv3, 256, (1, n))
    #line 3-2
    conv3_2 = conv2d(conv3, 256, (n, 1))
    #line 4
    conv4_1 = conv2d(input_layer, 384, 1)
    conv4_2 = conv2d(conv4_1, 448, (1, n))
    conv4_3 = conv2d(conv4_2, 512, (n, 1))
    #line 4a
    conv4a = conv2d(conv4_3, 256, (n, 1))
    #line 4b
    conv4b = conv2d(conv4_3, 256, (1, n))
    #filter concat
    x = layers.concatenate([conv1_1, conv2_1, conv3_1, conv3_2, conv4a, conv4b], axis=-1)
    
    return x

def reductionA(input_layer, k=192, l=224, m=256, n=384):
    #maxpool
    maxpool = layers.MaxPooling2D(pool_size=3, strides=2, padding='valid')(input_layer)
    #line 1
    conv1_1 = conv2d(input_layer, n, 3, strides=2, padding='valid')
    #line 2
    conv2_1 = conv2d(input_layer, k, 1)
    conv2_2 = conv2d(conv2_1, l, 3)
    conv2_3 = conv2d(conv2_2, m, 3, strides=2, padding='valid')
    #filter concat
    x = layers.concatenate([conv1_1, conv2_3, maxpool], axis=-1)
    
    return x

def reductionB(input_layer):
    #maxpool
    maxpool = layers.MaxPooling2D(pool_size=3, strides=2, padding='valid')(input_layer)
    #line 1
    conv1_1 = conv2d(input_layer, 192, 1)
    conv1_2 = conv2d(conv1_1, 192, 3, strides=2, padding='valid')
    #line 2
    conv2_1 = conv2d(input_layer, 256, 1)
    conv2_2 = conv2d(conv2_1, 256, (1, 7))
    conv2_3 = conv2d(conv2_2, 320, (7, 1))
    conv2_4 = conv2d(conv2_3, 320, 3, strides=2, padding='valid')
    #filter concat
    x = layers.concatenate([conv1_2, conv2_4, maxpool], axis=-1)
    
    return x

# %%
def inceptionV4(input_shape, classes):
    _input = _input = keras.layers.Input(shape=input_shape)
    #stem
    x = stem(_input)
    #4 x Inception-A
    for _ in range(4):
        x = inceptionA(x)
    #Reduction-A
    x = reductionA(x)
    #7 x Inception-B
    for _ in range(7):
        x = inceptionB(x)
    #reduction-B
    x = reductionB(x)
    #3 x Inception-C
    for _ in range(3):
        x = inceptionC(x)
    #avgpooling
    x = layers.AveragePooling2D(8)(x)
    #dropout
    x = layers.Dropout(0.2)(x)
    x = layers.Flatten()(x)
    #output
    output = layers.Dense(classes, activation='softmax')(x)
    return keras.Model(_input, output, name="Inception-v4")

# %%
Inceptionv4 = inceptionV4((299,299,3), classes=10)
Inceptionv4.summary()
# Out:
# Model: "Inception-v4"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 299, 299, 3  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 149, 149, 32  864         ['input_1[0][0]']
#                                 )
#
#  batch_normalization (BatchNorm  (None, 149, 149, 32  96         ['conv2d[0][0]']
#  alization)                     )
#
#  activation (Activation)        (None, 149, 149, 32  0           ['batch_normalization[0][0]']
#                                 )
#
#  conv2d_1 (Conv2D)              (None, 147, 147, 32  9216        ['activation[0][0]']
#                                 )
#
#  batch_normalization_1 (BatchNo  (None, 147, 147, 32  96         ['conv2d_1[0][0]']
#  rmalization)                   )
#
#  activation_1 (Activation)      (None, 147, 147, 32  0           ['batch_normalization_1[0][0]']
#                                 )
#
#  conv2d_2 (Conv2D)              (None, 147, 147, 64  18432       ['activation_1[0][0]']
#                                 )
#
#  batch_normalization_2 (BatchNo  (None, 147, 147, 64  192        ['conv2d_2[0][0]']
#  rmalization)                   )
#
#  activation_2 (Activation)      (None, 147, 147, 64  0           ['batch_normalization_2[0][0]']
#                                 )
#
#  conv2d_3 (Conv2D)              (None, 73, 73, 96)   55296       ['activation_2[0][0]']
#
#  batch_normalization_3 (BatchNo  (None, 73, 73, 96)  288         ['conv2d_3[0][0]']
#  rmalization)
#
#  activation_3 (Activation)      (None, 73, 73, 96)   0           ['batch_normalization_3[0][0]']
#
#  max_pooling2d (MaxPooling2D)   (None, 73, 73, 64)   0           ['activation_2[0][0]']
#
#  concatenate (Concatenate)      (None, 73, 73, 160)  0           ['activation_3[0][0]',
#                                                                   'max_pooling2d[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 73, 73, 64)   10240       ['concatenate[0][0]']
#
#  batch_normalization_6 (BatchNo  (None, 73, 73, 64)  192         ['conv2d_6[0][0]']
#  rmalization)
#
#  activation_6 (Activation)      (None, 73, 73, 64)   0           ['batch_normalization_6[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 73, 73, 64)   28672       ['activation_6[0][0]']
#
#  batch_normalization_7 (BatchNo  (None, 73, 73, 64)  192         ['conv2d_7[0][0]']
#  rmalization)
#
#  activation_7 (Activation)      (None, 73, 73, 64)   0           ['batch_normalization_7[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 73, 73, 64)   10240       ['concatenate[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 73, 73, 64)   28672       ['activation_7[0][0]']
#
#  batch_normalization_4 (BatchNo  (None, 73, 73, 64)  192         ['conv2d_4[0][0]']
#  rmalization)
#
#  batch_normalization_8 (BatchNo  (None, 73, 73, 64)  192         ['conv2d_8[0][0]']
#  rmalization)
#
#  activation_4 (Activation)      (None, 73, 73, 64)   0           ['batch_normalization_4[0][0]']
#
#  activation_8 (Activation)      (None, 73, 73, 64)   0           ['batch_normalization_8[0][0]']
#
#  conv2d_5 (Conv2D)              (None, 71, 71, 96)   55296       ['activation_4[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 71, 71, 96)   55296       ['activation_8[0][0]']
#
#  batch_normalization_5 (BatchNo  (None, 71, 71, 96)  288         ['conv2d_5[0][0]']
#  rmalization)
#
#  batch_normalization_9 (BatchNo  (None, 71, 71, 96)  288         ['conv2d_9[0][0]']
#  rmalization)
#
#  activation_5 (Activation)      (None, 71, 71, 96)   0           ['batch_normalization_5[0][0]']
#
#  activation_9 (Activation)      (None, 71, 71, 96)   0           ['batch_normalization_9[0][0]']
#
#  concatenate_1 (Concatenate)    (None, 71, 71, 192)  0           ['activation_5[0][0]',
#                                                                   'activation_9[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 71, 71, 64)   12288       ['concatenate_1[0][0]']
#
#  batch_normalization_14 (BatchN  (None, 71, 71, 64)  192         ['conv2d_14[0][0]']
#  ormalization)
#
#  activation_14 (Activation)     (None, 71, 71, 64)   0           ['batch_normalization_14[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 71, 71, 64)   12288       ['concatenate_1[0][0]']
#
#  conv2d_15 (Conv2D)             (None, 71, 71, 96)   55296       ['activation_14[0][0]']
#
#  batch_normalization_12 (BatchN  (None, 71, 71, 64)  192         ['conv2d_12[0][0]']
#  ormalization)
#
#  batch_normalization_15 (BatchN  (None, 71, 71, 96)  288         ['conv2d_15[0][0]']
#  ormalization)
#
#  average_pooling2d (AveragePool  (None, 71, 71, 192)  0          ['concatenate_1[0][0]']
#  ing2D)
#
#  activation_12 (Activation)     (None, 71, 71, 64)   0           ['batch_normalization_12[0][0]']
#
#  activation_15 (Activation)     (None, 71, 71, 96)   0           ['batch_normalization_15[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 71, 71, 96)   18432       ['average_pooling2d[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 71, 71, 96)   18432       ['concatenate_1[0][0]']
#
#  conv2d_13 (Conv2D)             (None, 71, 71, 96)   55296       ['activation_12[0][0]']
#
#  conv2d_16 (Conv2D)             (None, 71, 71, 96)   82944       ['activation_15[0][0]']
#
#  batch_normalization_10 (BatchN  (None, 71, 71, 96)  288         ['conv2d_10[0][0]']
#  ormalization)
#
#  batch_normalization_11 (BatchN  (None, 71, 71, 96)  288         ['conv2d_11[0][0]']
#  ormalization)
#
#  batch_normalization_13 (BatchN  (None, 71, 71, 96)  288         ['conv2d_13[0][0]']
#  ormalization)
#
#  batch_normalization_16 (BatchN  (None, 71, 71, 96)  288         ['conv2d_16[0][0]']
#  ormalization)
#
#  activation_10 (Activation)     (None, 71, 71, 96)   0           ['batch_normalization_10[0][0]']
#
#  activation_11 (Activation)     (None, 71, 71, 96)   0           ['batch_normalization_11[0][0]']
#
#  activation_13 (Activation)     (None, 71, 71, 96)   0           ['batch_normalization_13[0][0]']
#
#  activation_16 (Activation)     (None, 71, 71, 96)   0           ['batch_normalization_16[0][0]']
#
#  concatenate_2 (Concatenate)    (None, 71, 71, 384)  0           ['activation_10[0][0]',
#                                                                   'activation_11[0][0]',
#                                                                   'activation_13[0][0]',
#                                                                   'activation_16[0][0]']
#
#  conv2d_21 (Conv2D)             (None, 71, 71, 64)   24576       ['concatenate_2[0][0]']
#
#  batch_normalization_21 (BatchN  (None, 71, 71, 64)  192         ['conv2d_21[0][0]']
#  ormalization)
#
#  activation_21 (Activation)     (None, 71, 71, 64)   0           ['batch_normalization_21[0][0]']
#
#  conv2d_19 (Conv2D)             (None, 71, 71, 64)   24576       ['concatenate_2[0][0]']
#
#  conv2d_22 (Conv2D)             (None, 71, 71, 96)   55296       ['activation_21[0][0]']
#
#  batch_normalization_19 (BatchN  (None, 71, 71, 64)  192         ['conv2d_19[0][0]']
#  ormalization)
#
#  batch_normalization_22 (BatchN  (None, 71, 71, 96)  288         ['conv2d_22[0][0]']
#  ormalization)
#
#  average_pooling2d_1 (AveragePo  (None, 71, 71, 384)  0          ['concatenate_2[0][0]']
#  oling2D)
#
#  activation_19 (Activation)     (None, 71, 71, 64)   0           ['batch_normalization_19[0][0]']
#
#  activation_22 (Activation)     (None, 71, 71, 96)   0           ['batch_normalization_22[0][0]']
#
#  conv2d_17 (Conv2D)             (None, 71, 71, 96)   36864       ['average_pooling2d_1[0][0]']
#
#  conv2d_18 (Conv2D)             (None, 71, 71, 96)   36864       ['concatenate_2[0][0]']
#
#  conv2d_20 (Conv2D)             (None, 71, 71, 96)   55296       ['activation_19[0][0]']
#
#  conv2d_23 (Conv2D)             (None, 71, 71, 96)   82944       ['activation_22[0][0]']
#
#  batch_normalization_17 (BatchN  (None, 71, 71, 96)  288         ['conv2d_17[0][0]']
#  ormalization)
#
#  batch_normalization_18 (BatchN  (None, 71, 71, 96)  288         ['conv2d_18[0][0]']
#  ormalization)
#
#  batch_normalization_20 (BatchN  (None, 71, 71, 96)  288         ['conv2d_20[0][0]']
#  ormalization)
#
#  batch_normalization_23 (BatchN  (None, 71, 71, 96)  288         ['conv2d_23[0][0]']
#  ormalization)
#
#  activation_17 (Activation)     (None, 71, 71, 96)   0           ['batch_normalization_17[0][0]']
#
#  activation_18 (Activation)     (None, 71, 71, 96)   0           ['batch_normalization_18[0][0]']
#
#  activation_20 (Activation)     (None, 71, 71, 96)   0           ['batch_normalization_20[0][0]']
#
#  activation_23 (Activation)     (None, 71, 71, 96)   0           ['batch_normalization_23[0][0]']
#
#  concatenate_3 (Concatenate)    (None, 71, 71, 384)  0           ['activation_17[0][0]',
#                                                                   'activation_18[0][0]',
#                                                                   'activation_20[0][0]',
#                                                                   'activation_23[0][0]']
#
#  conv2d_28 (Conv2D)             (None, 71, 71, 64)   24576       ['concatenate_3[0][0]']
#
#  batch_normalization_28 (BatchN  (None, 71, 71, 64)  192         ['conv2d_28[0][0]']
#  ormalization)
#
#  activation_28 (Activation)     (None, 71, 71, 64)   0           ['batch_normalization_28[0][0]']
#
#  conv2d_26 (Conv2D)             (None, 71, 71, 64)   24576       ['concatenate_3[0][0]']
#
#  conv2d_29 (Conv2D)             (None, 71, 71, 96)   55296       ['activation_28[0][0]']
#
#  batch_normalization_26 (BatchN  (None, 71, 71, 64)  192         ['conv2d_26[0][0]']
#  ormalization)
#
#  batch_normalization_29 (BatchN  (None, 71, 71, 96)  288         ['conv2d_29[0][0]']
#  ormalization)
#
#  average_pooling2d_2 (AveragePo  (None, 71, 71, 384)  0          ['concatenate_3[0][0]']
#  oling2D)
#
#  activation_26 (Activation)     (None, 71, 71, 64)   0           ['batch_normalization_26[0][0]']
#
#  activation_29 (Activation)     (None, 71, 71, 96)   0           ['batch_normalization_29[0][0]']
#
#  conv2d_24 (Conv2D)             (None, 71, 71, 96)   36864       ['average_pooling2d_2[0][0]']
#
#  conv2d_25 (Conv2D)             (None, 71, 71, 96)   36864       ['concatenate_3[0][0]']
#
#  conv2d_27 (Conv2D)             (None, 71, 71, 96)   55296       ['activation_26[0][0]']
#
#  conv2d_30 (Conv2D)             (None, 71, 71, 96)   82944       ['activation_29[0][0]']
#
#  batch_normalization_24 (BatchN  (None, 71, 71, 96)  288         ['conv2d_24[0][0]']
#  ormalization)
#
#  batch_normalization_25 (BatchN  (None, 71, 71, 96)  288         ['conv2d_25[0][0]']
#  ormalization)
#
#  batch_normalization_27 (BatchN  (None, 71, 71, 96)  288         ['conv2d_27[0][0]']
#  ormalization)
#
#  batch_normalization_30 (BatchN  (None, 71, 71, 96)  288         ['conv2d_30[0][0]']
#  ormalization)
#
#  activation_24 (Activation)     (None, 71, 71, 96)   0           ['batch_normalization_24[0][0]']
#
#  activation_25 (Activation)     (None, 71, 71, 96)   0           ['batch_normalization_25[0][0]']
#
#  activation_27 (Activation)     (None, 71, 71, 96)   0           ['batch_normalization_27[0][0]']
#
#  activation_30 (Activation)     (None, 71, 71, 96)   0           ['batch_normalization_30[0][0]']
#
#  concatenate_4 (Concatenate)    (None, 71, 71, 384)  0           ['activation_24[0][0]',
#                                                                   'activation_25[0][0]',
#                                                                   'activation_27[0][0]',
#                                                                   'activation_30[0][0]']
#
#  conv2d_35 (Conv2D)             (None, 71, 71, 64)   24576       ['concatenate_4[0][0]']
#
#  batch_normalization_35 (BatchN  (None, 71, 71, 64)  192         ['conv2d_35[0][0]']
#  ormalization)
#
#  activation_35 (Activation)     (None, 71, 71, 64)   0           ['batch_normalization_35[0][0]']
#
#  conv2d_33 (Conv2D)             (None, 71, 71, 64)   24576       ['concatenate_4[0][0]']
#
#  conv2d_36 (Conv2D)             (None, 71, 71, 96)   55296       ['activation_35[0][0]']
#
#  batch_normalization_33 (BatchN  (None, 71, 71, 64)  192         ['conv2d_33[0][0]']
#  ormalization)
#
#  batch_normalization_36 (BatchN  (None, 71, 71, 96)  288         ['conv2d_36[0][0]']
#  ormalization)
#
#  average_pooling2d_3 (AveragePo  (None, 71, 71, 384)  0          ['concatenate_4[0][0]']
#  oling2D)
#
#  activation_33 (Activation)     (None, 71, 71, 64)   0           ['batch_normalization_33[0][0]']
#
#  activation_36 (Activation)     (None, 71, 71, 96)   0           ['batch_normalization_36[0][0]']
#
#  conv2d_31 (Conv2D)             (None, 71, 71, 96)   36864       ['average_pooling2d_3[0][0]']
#
#  conv2d_32 (Conv2D)             (None, 71, 71, 96)   36864       ['concatenate_4[0][0]']
#
#  conv2d_34 (Conv2D)             (None, 71, 71, 96)   55296       ['activation_33[0][0]']
#
#  conv2d_37 (Conv2D)             (None, 71, 71, 96)   82944       ['activation_36[0][0]']
#
#  batch_normalization_31 (BatchN  (None, 71, 71, 96)  288         ['conv2d_31[0][0]']
#  ormalization)
#
#  batch_normalization_32 (BatchN  (None, 71, 71, 96)  288         ['conv2d_32[0][0]']
#  ormalization)
#
#  batch_normalization_34 (BatchN  (None, 71, 71, 96)  288         ['conv2d_34[0][0]']
#  ormalization)
#
#  batch_normalization_37 (BatchN  (None, 71, 71, 96)  288         ['conv2d_37[0][0]']
#  ormalization)
#
#  activation_31 (Activation)     (None, 71, 71, 96)   0           ['batch_normalization_31[0][0]']
#
#  activation_32 (Activation)     (None, 71, 71, 96)   0           ['batch_normalization_32[0][0]']
#
#  activation_34 (Activation)     (None, 71, 71, 96)   0           ['batch_normalization_34[0][0]']
#
#  activation_37 (Activation)     (None, 71, 71, 96)   0           ['batch_normalization_37[0][0]']
#
#  concatenate_5 (Concatenate)    (None, 71, 71, 384)  0           ['activation_31[0][0]',
#                                                                   'activation_32[0][0]',
#                                                                   'activation_34[0][0]',
#                                                                   'activation_37[0][0]']
#
#  conv2d_39 (Conv2D)             (None, 71, 71, 192)  73728       ['concatenate_5[0][0]']
#
#  batch_normalization_39 (BatchN  (None, 71, 71, 192)  576        ['conv2d_39[0][0]']
#  ormalization)
#
#  activation_39 (Activation)     (None, 71, 71, 192)  0           ['batch_normalization_39[0][0]']
#
#  conv2d_40 (Conv2D)             (None, 71, 71, 224)  387072      ['activation_39[0][0]']
#
#  batch_normalization_40 (BatchN  (None, 71, 71, 224)  672        ['conv2d_40[0][0]']
#  ormalization)
#
#  activation_40 (Activation)     (None, 71, 71, 224)  0           ['batch_normalization_40[0][0]']
#
#  conv2d_38 (Conv2D)             (None, 35, 35, 384)  1327104     ['concatenate_5[0][0]']
#
#  conv2d_41 (Conv2D)             (None, 35, 35, 256)  516096      ['activation_40[0][0]']
#
#  batch_normalization_38 (BatchN  (None, 35, 35, 384)  1152       ['conv2d_38[0][0]']
#  ormalization)
#
#  batch_normalization_41 (BatchN  (None, 35, 35, 256)  768        ['conv2d_41[0][0]']
#  ormalization)
#
#  activation_38 (Activation)     (None, 35, 35, 384)  0           ['batch_normalization_38[0][0]']
#
#  activation_41 (Activation)     (None, 35, 35, 256)  0           ['batch_normalization_41[0][0]']
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 35, 35, 384)  0          ['concatenate_5[0][0]']
#
#  concatenate_6 (Concatenate)    (None, 35, 35, 1024  0           ['activation_38[0][0]',
#                                 )                                 'activation_41[0][0]',
#                                                                   'max_pooling2d_1[0][0]']
#
#  conv2d_47 (Conv2D)             (None, 35, 35, 192)  196608      ['concatenate_6[0][0]']
#
#  batch_normalization_47 (BatchN  (None, 35, 35, 192)  576        ['conv2d_47[0][0]']
#  ormalization)
#
#  activation_47 (Activation)     (None, 35, 35, 192)  0           ['batch_normalization_47[0][0]']
#
#  conv2d_48 (Conv2D)             (None, 35, 35, 192)  258048      ['activation_47[0][0]']
#
#  batch_normalization_48 (BatchN  (None, 35, 35, 192)  576        ['conv2d_48[0][0]']
#  ormalization)
#
#  activation_48 (Activation)     (None, 35, 35, 192)  0           ['batch_normalization_48[0][0]']
#
#  conv2d_44 (Conv2D)             (None, 35, 35, 192)  196608      ['concatenate_6[0][0]']
#
#  conv2d_49 (Conv2D)             (None, 35, 35, 224)  301056      ['activation_48[0][0]']
#
#  batch_normalization_44 (BatchN  (None, 35, 35, 192)  576        ['conv2d_44[0][0]']
#  ormalization)
#
#  batch_normalization_49 (BatchN  (None, 35, 35, 224)  672        ['conv2d_49[0][0]']
#  ormalization)
#
#  activation_44 (Activation)     (None, 35, 35, 192)  0           ['batch_normalization_44[0][0]']
#
#  activation_49 (Activation)     (None, 35, 35, 224)  0           ['batch_normalization_49[0][0]']
#
#  conv2d_45 (Conv2D)             (None, 35, 35, 224)  301056      ['activation_44[0][0]']
#
#  conv2d_50 (Conv2D)             (None, 35, 35, 224)  351232      ['activation_49[0][0]']
#
#  batch_normalization_45 (BatchN  (None, 35, 35, 224)  672        ['conv2d_45[0][0]']
#  ormalization)
#
#  batch_normalization_50 (BatchN  (None, 35, 35, 224)  672        ['conv2d_50[0][0]']
#  ormalization)
#
#  average_pooling2d_4 (AveragePo  (None, 35, 35, 1024  0          ['concatenate_6[0][0]']
#  oling2D)                       )
#
#  activation_45 (Activation)     (None, 35, 35, 224)  0           ['batch_normalization_45[0][0]']
#
#  activation_50 (Activation)     (None, 35, 35, 224)  0           ['batch_normalization_50[0][0]']
#
#  conv2d_42 (Conv2D)             (None, 35, 35, 128)  131072      ['average_pooling2d_4[0][0]']
#
#  conv2d_43 (Conv2D)             (None, 35, 35, 384)  393216      ['concatenate_6[0][0]']
#
#  conv2d_46 (Conv2D)             (None, 35, 35, 256)  401408      ['activation_45[0][0]']
#
#  conv2d_51 (Conv2D)             (None, 35, 35, 256)  401408      ['activation_50[0][0]']
#
#  batch_normalization_42 (BatchN  (None, 35, 35, 128)  384        ['conv2d_42[0][0]']
#  ormalization)
#
#  batch_normalization_43 (BatchN  (None, 35, 35, 384)  1152       ['conv2d_43[0][0]']
#  ormalization)
#
#  batch_normalization_46 (BatchN  (None, 35, 35, 256)  768        ['conv2d_46[0][0]']
#  ormalization)
#
#  batch_normalization_51 (BatchN  (None, 35, 35, 256)  768        ['conv2d_51[0][0]']
#  ormalization)
#
#  activation_42 (Activation)     (None, 35, 35, 128)  0           ['batch_normalization_42[0][0]']
#
#  activation_43 (Activation)     (None, 35, 35, 384)  0           ['batch_normalization_43[0][0]']
#
#  activation_46 (Activation)     (None, 35, 35, 256)  0           ['batch_normalization_46[0][0]']
#
#  activation_51 (Activation)     (None, 35, 35, 256)  0           ['batch_normalization_51[0][0]']
#
#  concatenate_7 (Concatenate)    (None, 35, 35, 1024  0           ['activation_42[0][0]',
#                                 )                                 'activation_43[0][0]',
#                                                                   'activation_46[0][0]',
#                                                                   'activation_51[0][0]']
#
#  conv2d_57 (Conv2D)             (None, 35, 35, 192)  196608      ['concatenate_7[0][0]']
#
#  batch_normalization_57 (BatchN  (None, 35, 35, 192)  576        ['conv2d_57[0][0]']
#  ormalization)
#
#  activation_57 (Activation)     (None, 35, 35, 192)  0           ['batch_normalization_57[0][0]']
#
#  conv2d_58 (Conv2D)             (None, 35, 35, 192)  258048      ['activation_57[0][0]']
#
#  batch_normalization_58 (BatchN  (None, 35, 35, 192)  576        ['conv2d_58[0][0]']
#  ormalization)
#
#  activation_58 (Activation)     (None, 35, 35, 192)  0           ['batch_normalization_58[0][0]']
#
#  conv2d_54 (Conv2D)             (None, 35, 35, 192)  196608      ['concatenate_7[0][0]']
#
#  conv2d_59 (Conv2D)             (None, 35, 35, 224)  301056      ['activation_58[0][0]']
#
#  batch_normalization_54 (BatchN  (None, 35, 35, 192)  576        ['conv2d_54[0][0]']
#  ormalization)
#
#  batch_normalization_59 (BatchN  (None, 35, 35, 224)  672        ['conv2d_59[0][0]']
#  ormalization)
#
#  activation_54 (Activation)     (None, 35, 35, 192)  0           ['batch_normalization_54[0][0]']
#
#  activation_59 (Activation)     (None, 35, 35, 224)  0           ['batch_normalization_59[0][0]']
#
#  conv2d_55 (Conv2D)             (None, 35, 35, 224)  301056      ['activation_54[0][0]']
#
#  conv2d_60 (Conv2D)             (None, 35, 35, 224)  351232      ['activation_59[0][0]']
#
#  batch_normalization_55 (BatchN  (None, 35, 35, 224)  672        ['conv2d_55[0][0]']
#  ormalization)
#
#  batch_normalization_60 (BatchN  (None, 35, 35, 224)  672        ['conv2d_60[0][0]']
#  ormalization)
#
#  average_pooling2d_5 (AveragePo  (None, 35, 35, 1024  0          ['concatenate_7[0][0]']
#  oling2D)                       )
#
#  activation_55 (Activation)     (None, 35, 35, 224)  0           ['batch_normalization_55[0][0]']
#
#  activation_60 (Activation)     (None, 35, 35, 224)  0           ['batch_normalization_60[0][0]']
#
#  conv2d_52 (Conv2D)             (None, 35, 35, 128)  131072      ['average_pooling2d_5[0][0]']
#
#  conv2d_53 (Conv2D)             (None, 35, 35, 384)  393216      ['concatenate_7[0][0]']
#
#  conv2d_56 (Conv2D)             (None, 35, 35, 256)  401408      ['activation_55[0][0]']
#
#  conv2d_61 (Conv2D)             (None, 35, 35, 256)  401408      ['activation_60[0][0]']
#
#  batch_normalization_52 (BatchN  (None, 35, 35, 128)  384        ['conv2d_52[0][0]']
# ...
#
#  activation_134 (Activation)    (None, 17, 17, 448)  0           ['batch_normalization_134[0][0]']
#
#  conv2d_130 (Conv2D)            (None, 17, 17, 384)  589824      ['concatenate_15[0][0]']
#
#  conv2d_135 (Conv2D)            (None, 17, 17, 512)  688128      ['activation_134[0][0]']
#
#  batch_normalization_130 (Batch  (None, 17, 17, 384)  1152       ['conv2d_130[0][0]']
#  Normalization)
#
#  batch_normalization_135 (Batch  (None, 17, 17, 512)  1536       ['conv2d_135[0][0]']
#  Normalization)
#
#  average_pooling2d_12 (AverageP  (None, 17, 17, 1536  0          ['concatenate_15[0][0]']
#  ooling2D)                      )
#
#  activation_130 (Activation)    (None, 17, 17, 384)  0           ['batch_normalization_130[0][0]']
#
#  activation_135 (Activation)    (None, 17, 17, 512)  0           ['batch_normalization_135[0][0]']
#
#  conv2d_128 (Conv2D)            (None, 17, 17, 256)  393216      ['average_pooling2d_12[0][0]']
#
#  conv2d_129 (Conv2D)            (None, 17, 17, 256)  393216      ['concatenate_15[0][0]']
#
#  conv2d_131 (Conv2D)            (None, 17, 17, 256)  294912      ['activation_130[0][0]']
#
#  conv2d_132 (Conv2D)            (None, 17, 17, 256)  294912      ['activation_130[0][0]']
#
#  conv2d_136 (Conv2D)            (None, 17, 17, 256)  393216      ['activation_135[0][0]']
#
#  conv2d_137 (Conv2D)            (None, 17, 17, 256)  393216      ['activation_135[0][0]']
#
#  batch_normalization_128 (Batch  (None, 17, 17, 256)  768        ['conv2d_128[0][0]']
#  Normalization)
#
#  batch_normalization_129 (Batch  (None, 17, 17, 256)  768        ['conv2d_129[0][0]']
#  Normalization)
#
#  batch_normalization_131 (Batch  (None, 17, 17, 256)  768        ['conv2d_131[0][0]']
#  Normalization)
#
#  batch_normalization_132 (Batch  (None, 17, 17, 256)  768        ['conv2d_132[0][0]']
#  Normalization)
#
#  batch_normalization_136 (Batch  (None, 17, 17, 256)  768        ['conv2d_136[0][0]']
#  Normalization)
#
#  batch_normalization_137 (Batch  (None, 17, 17, 256)  768        ['conv2d_137[0][0]']
#  Normalization)
#
#  activation_128 (Activation)    (None, 17, 17, 256)  0           ['batch_normalization_128[0][0]']
#
#  activation_129 (Activation)    (None, 17, 17, 256)  0           ['batch_normalization_129[0][0]']
#
#  activation_131 (Activation)    (None, 17, 17, 256)  0           ['batch_normalization_131[0][0]']
#
#  activation_132 (Activation)    (None, 17, 17, 256)  0           ['batch_normalization_132[0][0]']
#
#  activation_136 (Activation)    (None, 17, 17, 256)  0           ['batch_normalization_136[0][0]']
#
#  activation_137 (Activation)    (None, 17, 17, 256)  0           ['batch_normalization_137[0][0]']
#
#  concatenate_16 (Concatenate)   (None, 17, 17, 1536  0           ['activation_128[0][0]',
#                                 )                                 'activation_129[0][0]',
#                                                                   'activation_131[0][0]',
#                                                                   'activation_132[0][0]',
#                                                                   'activation_136[0][0]',
#                                                                   'activation_137[0][0]']
#
#  conv2d_143 (Conv2D)            (None, 17, 17, 384)  589824      ['concatenate_16[0][0]']
#
#  batch_normalization_143 (Batch  (None, 17, 17, 384)  1152       ['conv2d_143[0][0]']
#  Normalization)
#
#  activation_143 (Activation)    (None, 17, 17, 384)  0           ['batch_normalization_143[0][0]']
#
#  conv2d_144 (Conv2D)            (None, 17, 17, 448)  516096      ['activation_143[0][0]']
#
#  batch_normalization_144 (Batch  (None, 17, 17, 448)  1344       ['conv2d_144[0][0]']
#  Normalization)
#
#  activation_144 (Activation)    (None, 17, 17, 448)  0           ['batch_normalization_144[0][0]']
#
#  conv2d_140 (Conv2D)            (None, 17, 17, 384)  589824      ['concatenate_16[0][0]']
#
#  conv2d_145 (Conv2D)            (None, 17, 17, 512)  688128      ['activation_144[0][0]']
#
#  batch_normalization_140 (Batch  (None, 17, 17, 384)  1152       ['conv2d_140[0][0]']
#  Normalization)
#
#  batch_normalization_145 (Batch  (None, 17, 17, 512)  1536       ['conv2d_145[0][0]']
#  Normalization)
#
#  average_pooling2d_13 (AverageP  (None, 17, 17, 1536  0          ['concatenate_16[0][0]']
#  ooling2D)                      )
#
#  activation_140 (Activation)    (None, 17, 17, 384)  0           ['batch_normalization_140[0][0]']
#
#  activation_145 (Activation)    (None, 17, 17, 512)  0           ['batch_normalization_145[0][0]']
#
#  conv2d_138 (Conv2D)            (None, 17, 17, 256)  393216      ['average_pooling2d_13[0][0]']
#
#  conv2d_139 (Conv2D)            (None, 17, 17, 256)  393216      ['concatenate_16[0][0]']
#
#  conv2d_141 (Conv2D)            (None, 17, 17, 256)  294912      ['activation_140[0][0]']
#
#  conv2d_142 (Conv2D)            (None, 17, 17, 256)  294912      ['activation_140[0][0]']
#
#  conv2d_146 (Conv2D)            (None, 17, 17, 256)  393216      ['activation_145[0][0]']
#
#  conv2d_147 (Conv2D)            (None, 17, 17, 256)  393216      ['activation_145[0][0]']
#
#  batch_normalization_138 (Batch  (None, 17, 17, 256)  768        ['conv2d_138[0][0]']
#  Normalization)
#
#  batch_normalization_139 (Batch  (None, 17, 17, 256)  768        ['conv2d_139[0][0]']
#  Normalization)
#
#  batch_normalization_141 (Batch  (None, 17, 17, 256)  768        ['conv2d_141[0][0]']
#  Normalization)
#
#  batch_normalization_142 (Batch  (None, 17, 17, 256)  768        ['conv2d_142[0][0]']
#  Normalization)
#
#  batch_normalization_146 (Batch  (None, 17, 17, 256)  768        ['conv2d_146[0][0]']
#  Normalization)
#
#  batch_normalization_147 (Batch  (None, 17, 17, 256)  768        ['conv2d_147[0][0]']
#  Normalization)
#
#  activation_138 (Activation)    (None, 17, 17, 256)  0           ['batch_normalization_138[0][0]']
#
#  activation_139 (Activation)    (None, 17, 17, 256)  0           ['batch_normalization_139[0][0]']
#
#  activation_141 (Activation)    (None, 17, 17, 256)  0           ['batch_normalization_141[0][0]']
#
#  activation_142 (Activation)    (None, 17, 17, 256)  0           ['batch_normalization_142[0][0]']
#
#  activation_146 (Activation)    (None, 17, 17, 256)  0           ['batch_normalization_146[0][0]']
#
#  activation_147 (Activation)    (None, 17, 17, 256)  0           ['batch_normalization_147[0][0]']
#
#  concatenate_17 (Concatenate)   (None, 17, 17, 1536  0           ['activation_138[0][0]',
#                                 )                                 'activation_139[0][0]',
#                                                                   'activation_141[0][0]',
#                                                                   'activation_142[0][0]',
#                                                                   'activation_146[0][0]',
#                                                                   'activation_147[0][0]']
#
#  average_pooling2d_14 (AverageP  (None, 2, 2, 1536)  0           ['concatenate_17[0][0]']
#  ooling2D)
#
#  dropout (Dropout)              (None, 2, 2, 1536)   0           ['average_pooling2d_14[0][0]']
#
#  flatten (Flatten)              (None, 6144)         0           ['dropout[0][0]']
#
#  dense (Dense)                  (None, 10)           61450       ['flatten[0][0]']
#
# ==================================================================================================
# Total params: 40,842,058
# Trainable params: 40,779,274
# Non-trainable params: 62,784
# __________________________________________________________________________________________________

# %%
Inceptionv4.compile(loss='sparse_categorical_crossentropy',
              optimizer='Adam',
              metrics=['accuracy'])

# %%
checkpoint_filepath = '/content/drive/MyDrive/MLh5/inceptionv4.h5'
model_checkpoint_callback = [tf.keras.callbacks.ModelCheckpoint(filepath=checkpoint_filepath, save_best_only=True)]
#5 epochs (each epoch need around X mins, it is time-consuming.)
history = Inceptionv4.fit(
    train_ds,
    epochs=10,
    validation_data = test_ds,
    validation_freq=1,
    callbacks=model_checkpoint_callback
)

#RAM exhaustion...............................cant train the model
# Out:
# Epoch 1/10

# %%
pd.DataFrame(history.history).plot(figsize=(8, 5))
plt.grid(True)
plt.gca().set_ylim(0, 2.3) # set the vertical range to [0-1]
plt.show()
